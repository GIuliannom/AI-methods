# %% [markdown]
# ### Simple visualization
#
# Testing and learning a few useful and simple visualization methods

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Auto.csv")
df = pd.DataFrame(data)

# %%
df = df.dropna()
df #dropping the NaN
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
print('min\n', np.min(df)) #using np.min and np.max to get the range of the data
print()
print('max\n',np.max(df))
# Out:
# min
#  mpg                                   9
# cylinders                             3
# displacement                         68
# horsepower                          100
# weight                             1613
# acceleration                          8
# year                                 70
# origin                                1
# name            amc ambassador brougham
# dtype: object
#
# max
#  mpg                         46.6
# cylinders                      8
# displacement                 455
# horsepower                     ?
# weight                      5140
# acceleration                24.8
# year                          82
# origin                         3
# name            vw rabbit custom
# dtype: object

# %%
df.describe() #using describe to see the values that i got are correct
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df1 = df.drop(df.index[9:85])
df1 #dropping the rows 10 to 85
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
df1.describe() #using describe to find range, mean and standard deviation, easier if going to compare with df
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  321.000000  321.000000    321.000000   321.000000    321.000000
# mean    24.438629    5.370717    187.049844  2933.962617     15.723053
# std      7.908184    1.653486     99.635385   810.642938      2.680514
# min     11.000000    3.000000     68.000000  1649.000000      8.500000
# 25%     18.000000    4.000000    100.000000  2215.000000     14.000000
# 50%     23.900000    4.000000    145.000000  2795.000000     15.500000
# 75%     30.700000    6.000000    250.000000  3504.000000     17.300000
# max     46.600000    8.000000    455.000000  4997.000000     24.800000
#
#              year      origin
# count  321.000000  321.000000
# mean    77.152648    1.598131
# std      3.111230    0.816163
# min     70.000000    1.000000
# 25%     75.000000    1.000000
# 50%     77.000000    1.000000
# 75%     80.000000    2.000000
# max     82.000000    3.000000

# %%
import matplotlib.pyplot as plt

# %%
ax = pd.plotting.scatter_matrix(df,figsize = (10, 10))
plt.show()
# Out:
# /Users/giu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %%
data = pd.read_csv("CodParasite.txt", delimiter= '\t')
df = pd.DataFrame(data)
df
# Out:
#       Sample  Intensity  Prevalence  Year  Depth  Weight  Length  Sex  Stage  \
# 0          1        0.0           0  1999    220   148.0    26.0    0      0
# 1          2        0.0           0  1999    220   144.0    26.0    0      0
# 2          3        0.0           0  1999    220   146.0    27.0    0      0
# 3          4        0.0           0  1999    220   138.0    26.0    0      0
# 4          5        0.0           0  1999    220    40.0    17.0    0      0
# ...      ...        ...         ...   ...    ...     ...     ...  ...    ...
# 1249    1250       90.0           1  2001    228   224.0    31.0    1      1
# 1250    1251      104.0           1  2001    140   690.0    43.0    2      1
# 1251    1252      125.0           1  2001    140   754.0    44.0    2      1
# 1252    1253      128.0           1  2001    140  1270.0    55.0    2      4
# 1253    1254      257.0           1  2001    228   370.0    35.0    2      1
#
#       Age  Area
# 0       0     2
# ...

# %%
df['Log_int'] = np.log(df.Intensity + 1)
df #Adding one to intensity and taking the log of the column
# Out:
#       Sample  Intensity  Prevalence  Year  Depth  Weight  Length  Sex  Stage  \
# 0          1        0.0           0  1999    220   148.0    26.0    0      0
# 1          2        0.0           0  1999    220   144.0    26.0    0      0
# 2          3        0.0           0  1999    220   146.0    27.0    0      0
# 3          4        0.0           0  1999    220   138.0    26.0    0      0
# 4          5        0.0           0  1999    220    40.0    17.0    0      0
# ...      ...        ...         ...   ...    ...     ...     ...  ...    ...
# 1249    1250       90.0           1  2001    228   224.0    31.0    1      1
# 1250    1251      104.0           1  2001    140   690.0    43.0    2      1
# 1251    1252      125.0           1  2001    140   754.0    44.0    2      1
# 1252    1253      128.0           1  2001    140  1270.0    55.0    2      4
# 1253    1254      257.0           1  2001    228   370.0    35.0    2      1
#
#       Age  Area   Log_int
# ...

# %%
boxplot = df.boxplot(column = ['Log_int'], by =['Sex'], grid = True, figsize=[5,5]) #The boxplot of Log intensity conditional on sex

# %%
boxplot = df.boxplot(column = ['Log_int'], by =['Stage'], grid = True, figsize=[5,5]) #The boxplot of Log intensity conditional on Stage

# %%
boxplot = df.boxplot(column = ['Log_int'], by =['Year'], grid = True, figsize=[5,5]) #The boxplot of Log intensity conditional on Year

# %%
boxplot = df.boxplot(column = ['Log_int'], by =['Area'], grid = True, figsize=[5,5]) #The boxplot of Log intensity conditional on Area

# %%
data = pd.read_csv("Owls.txt", delimiter= '\t')
df = pd.DataFrame(data)
df
# Out:
#            Nest FoodTreatment SexParent  ArrivalTime  SiblingNegotiation  \
# 0    AutavauxTV      Deprived      Male        22.25                   4
# 1    AutavauxTV      Satiated      Male        22.38                   0
# 2    AutavauxTV      Deprived      Male        22.53                   2
# 3    AutavauxTV      Deprived      Male        22.56                   2
# 4    AutavauxTV      Deprived      Male        22.61                   2
# ..          ...           ...       ...          ...                 ...
# 594    Yvonnand      Deprived    Female        27.25                   7
# 595    Yvonnand      Deprived      Male        28.45                   5
# 596    Yvonnand      Deprived    Female        28.86                  15
# 597    Yvonnand      Deprived      Male        29.21                  10
# 598    Yvonnand      Satiated    Female        29.23                   0
#
#      BroodSize  NegPerChick
# 0            5     0.800000
# 1            5     0.000000
# ...

# %%
boxplot = df.boxplot(column = ['NegPerChick'], by =['SexParent'], grid = True, figsize=[5,5]) #The boxplot of negperchick conditional on sexparent

# %%
boxplot = df.boxplot(column = ['NegPerChick'], by =['FoodTreatment'], grid = True, figsize=[5,5]) #The boxplot of negperchick conditional on FoodTreatment

# %%
boxplot = df.boxplot(column = ['NegPerChick'], by =['FoodTreatment', 'SexParent'], grid = True, figsize=[10,10])#The boxplot of negperchick conditional on sexparent and foodtreatment

# %%
boxplot = df.boxplot(column = ['NegPerChick'], by =['Nest'], grid = True, figsize=[12,12])
plt.xticks(rotation=90)
plt.show()

# %%
scatter = df.plot.scatter(x='NegPerChick', y='SiblingNegotiation') #The scatterplot of negperchick vs sibling negotiation

# %%
df['Log_SN'] = np.log(df.SiblingNegotiation + 1)
df #the log of sibling negotiation + 1 to avoid error of log(0)
# Out:
#            Nest FoodTreatment SexParent  ArrivalTime  SiblingNegotiation  \
# 0    AutavauxTV      Deprived      Male        22.25                   4
# 1    AutavauxTV      Satiated      Male        22.38                   0
# 2    AutavauxTV      Deprived      Male        22.53                   2
# 3    AutavauxTV      Deprived      Male        22.56                   2
# 4    AutavauxTV      Deprived      Male        22.61                   2
# ..          ...           ...       ...          ...                 ...
# 594    Yvonnand      Deprived    Female        27.25                   7
# 595    Yvonnand      Deprived      Male        28.45                   5
# 596    Yvonnand      Deprived    Female        28.86                  15
# 597    Yvonnand      Deprived      Male        29.21                  10
# 598    Yvonnand      Satiated    Female        29.23                   0
#
#      BroodSize  NegPerChick    Log_SN
# 0            5     0.800000  1.609438
# ...

# %%
scatter = df.plot.scatter(x='ArrivalTime', y='Log_SN') #The scatter plot of log Sibling Negotiation by arrival time
